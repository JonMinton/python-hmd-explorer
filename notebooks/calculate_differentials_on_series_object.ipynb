# %%
import pandas as pd

# %% [markdown]
# reproduce function

# %%
def extract2dDataSeries(datatypeSelected, placesSelected, sexSelected):

    if datatypeSelected == 'births':
        d = pd.read_csv("../assets/data/births.csv")

        d2 = d.loc[
            (d['sex'] == sexSelected) & 
            (d['cntry'].isin(placesSelected))
            , ['country', 'year', 'number_of_births']
        ]
        # The following is for cases where more than one value is availbale for 
        # a particular sex and country combination
        d3 = d2.groupby(['country', 'year']).agg('mean').reset_index()
        d4 = d3.pivot(index='year', columns='country', values = 'number_of_births')
        
        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()

        return yearSeries, countriesSeriesDict
    elif datatypeSelected == 'deaths':
        d = pd.read_csv("../assets/data/deaths.csv")

        d2 = d.loc[
            (d['sex'] == sexSelected) & 
            (d['cntry'].isin(placesSelected))
            ,
            ['country', 'year', 'number_of_deaths']
        ]
        
        d3 = d2.groupby(['country', 'year']).agg('mean').reset_index()
        d4 = d3.pivot(index='year', columns='country', values = 'number_of_deaths')
        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()

        return yearSeries, countriesSeriesDict
    elif datatypeSelected == 'exposures':
        d = pd.read_csv("../assets/data/exposures.csv")

        d2 = d.loc[
            (d['sex'] == sexSelected) & 
            (d['cntry'].isin(placesSelected))
            , ['country', 'year', 'exposures_count']
        ]
        
        # The following is for cases where more than one value is availbale for 
        # a particular sex and country combination
        d3 = d2.groupby(['country', 'year']).agg('mean').reset_index()
        d4 = d3.pivot(index='year', columns='country', values = 'exposures_count')
        
        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()

        return yearSeries, countriesSeriesDict
        
    elif datatypeSelected == 'mx':
        d = pd.read_csv("../assets/data/Mx.csv")
        d2 = d.loc[
            (d['sex'] == sexSelected) & 
            (d['cntry'].isin(placesSelected))
            , ['country', 'year', 'mx']
        ]
        
        # The following is for cases where more than one value is availbale for 
        # a particular sex and country combination
        d3 = d2.groupby(['country', 'year']).agg('mean').reset_index()
        d4 = d3.pivot(index='year', columns='country', values = 'mx')
        
        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()
        
        return yearSeries, countriesSeriesDict
    elif datatypeSelected == 'population':
        d = pd.read_csv("../assets/data/population.csv")

        d2 = d.loc[
            (d['sex'] == sexSelected) & 
            (d['cntry'].isin(placesSelected))
            , ['country', 'year', 'population_count']
        ]
        
        # Have changed from mean to sum. Of course there should be more than one!
        d3 = d2.groupby(['country', 'year']).agg('sum').reset_index()
        d4 = d3.pivot(index='year', columns='country', values = 'population_count')
        
        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()
        
        return yearSeries, countriesSeriesDict

    elif datatypeSelected == 'lifetables':
        d = pd.read_csv("../assets/data/lifetables.csv")

            # Need to change total value of sex to both
        sexSelectedAdjusted = 'both' if sexSelected == 'total' else sexSelected
        d2 = d.loc[
            (d['sex'] == sexSelectedAdjusted) & 
            (d['cntry'].isin(placesSelected)) & 
            (d['age'] == 0)
            , ['country', 'year', 'ex']
        ]
        # Not sure this is needed
        d3 = d2.groupby(['country', 'year']).agg('mean').reset_index()
        
        d4 = d3.pivot(index='year', columns='country', values = 'ex')

        yearSeries = d4.index.to_list()
        countriesSeriesDict = d4.to_dict()

        return yearSeries, countriesSeriesDict

# %% [markdown]
# make request with reasonable inputs

# %%
datatypeSelected = 'lifetables'
placesSelected = ['AUS', 'FRATNP'] 
sexSelected = 'total'

# %% [markdown]
# run the function with the reasonable inputs

# %%
xSeries, ySeriesDict = extract2dDataSeries(datatypeSelected, placesSelected, sexSelected)

# %% [markdown]
# Now for each outer key in ySeriesDict, want to take the values of the object, convert to list, then apply the .diff method (I think)

# %%
ySeriesDict.keys()
# Out:
# dict_keys(['Australia', 'France'])

# %%
ySeriesDict.get('Australia').values()
# Out:
# dict_values([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 60.97, 62.83, 61.68, 62.48, 63.17, 62.88, 62.84, 62.91, 63.08, 64.9, 65.32, 65.6, 65.43, 64.79, 65.05, 65.19, 65.74, 65.76, 65.73, 66.16, 66.04, 65.79, 66.33, 67.96, 68.38, 67.92, 68.52, 68.47, 69.09, 69.0, 68.7, 69.11, 69.69, 69.86, 70.15, 70.04, 70.32, 70.86, 70.45, 70.87, 71.13, 70.91, 70.96, 70.57, 70.8, 70.68, 71.05, 70.68, 71.07, 70.65, 71.45, 71.77, 72.06, 71.85, 72.78, 72.79, 73.47, 73.74, 74.33, 74.57, 74.78, 74.72, 75.44, 75.51, 75.43, 76.07, 76.09, 76.35, 76.2, 77.04, 77.48, 77.47, 78.01, 77.86, 78.26, 78.35, 78.63, 79.03, 79.28, 79.62, 80.01, 80.06, 80.45, 80.74, 81.1, 81.27, 81.24, 81.43, 81.73, 82.02, 82.09, 82.3, 82.55, 82.52, 82.6, 82.81, 82.72, 83.26, 83.25, 83.67])

# %%
vals = [1, 2, 3, 4, 5]

[b - a for a, b in zip(vals, vals[1:])]
# Out:
# [1, 1, 1, 1]

# %% [markdown]
# This works as expected :)

# %%
vals = list(ySeriesDict.get('Australia').values())

diffVals = [b - a for a, b in zip(vals, vals[1:])]
diffVals
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.8599999999999994,
#  -1.1499999999999986,
#  0.7999999999999972,
#  0.6900000000000048,
#  -0.28999999999999915,
#  -0.03999999999999915,
#  0.06999999999999318,
#  0.1700000000000017,
#  1.8200000000000074,
#  0.4199999999999875,
#  0.28000000000000114,
#  -0.1699999999999875,
#  -0.6400000000000006,
#  0.2599999999999909,
#  0.14000000000000057,
#  0.5499999999999972,
#  0.020000000000010232,
#  -0.030000000000001137,
#  0.4299999999999926,
#  -0.11999999999999034,
#  -0.25,
#  0.539999999999992,
#  1.6299999999999955,
#  0.4200000000000017,
#  -0.45999999999999375,
#  0.5999999999999943,
#  -0.04999999999999716,
#  0.6200000000000045,
#  -0.09000000000000341,
#  -0.29999999999999716,
#  0.4099999999999966,
#  0.5799999999999983,
#  0.1700000000000017,
#  0.29000000000000625,
#  -0.10999999999999943,
#  0.2799999999999869,
#  0.5400000000000063,
#  -0.4099999999999966,
#  0.4200000000000017,
#  0.2599999999999909,
#  -0.21999999999999886,
#  0.04999999999999716,
#  -0.39000000000000057,
#  0.23000000000000398,
#  -0.11999999999999034,
#  0.36999999999999034,
#  -0.36999999999999034,
#  0.38999999999998636,
#  -0.4199999999999875,
#  0.7999999999999972,
#  0.3199999999999932,
#  0.29000000000000625,
#  -0.21000000000000796,
#  0.9300000000000068,
#  0.010000000000005116,
#  0.6799999999999926,
#  0.269999999999996,
#  0.5900000000000034,
#  0.23999999999999488,
#  0.21000000000000796,
#  -0.060000000000002274,
#  0.7199999999999989,
#  0.07000000000000739,
#  -0.0799999999999983,
#  0.6399999999999864,
#  0.020000000000010232,
#  0.2599999999999909,
#  -0.14999999999999147,
#  0.8400000000000034,
#  0.4399999999999977,
#  -0.010000000000005116,
#  0.5400000000000063,
#  -0.15000000000000568,
#  0.4000000000000057,
#  0.0899999999999892,
#  0.28000000000000114,
#  0.4000000000000057,
#  0.25,
#  0.3400000000000034,
#  0.39000000000000057,
#  0.04999999999999716,
#  0.39000000000000057,
#  0.28999999999999204,
#  0.35999999999999943,
#  0.1700000000000017,
#  -0.030000000000001137,
#  0.19000000000001194,
#  0.29999999999999716,
#  0.28999999999999204,
#  0.07000000000000739,
#  0.20999999999999375,
#  0.25,
#  -0.030000000000001137,
#  0.0799999999999983,
#  0.21000000000000796,
#  -0.09000000000000341,
#  0.5400000000000063,
#  -0.010000000000005116,
#  0.4200000000000017]

# %% [markdown]
# Ideally I'd like only the contents of the values to change, not the data type, i.e. to return a dict whose keys are the years and values are the differences between each year. I also want a single function which iterates over all keys

# %%
# ausKeys = ySeriesDict.get('Australia').keys()
# ausValues = ySeriesDict.get('Australia').values()

def getDiffsAsDict(dct):
    k = list(dct.keys())
    v = list(dct.values())
    vDiff = [b-a for a, b in zip(v, v[1:])]

    out = {k[i]: vDiff[i] for i in range(len(k) - 1)}
    return out

ausDiffDict = getDiffsAsDict(ySeriesDict.get('Australia'))

ausDiffDict
# Out:
# {1816: nan,
#  1817: nan,
#  1818: nan,
#  1819: nan,
#  1820: nan,
#  1821: nan,
#  1822: nan,
#  1823: nan,
#  1824: nan,
#  1825: nan,
#  1826: nan,
#  1827: nan,
#  1828: nan,
#  1829: nan,
#  1830: nan,
#  1831: nan,
#  1832: nan,
#  1833: nan,
#  1834: nan,
#  1835: nan,
#  1836: nan,
#  1837: nan,
#  1838: nan,
#  1839: nan,
#  1840: nan,
#  1841: nan,
#  1842: nan,
#  1843: nan,
#  1844: nan,
#  1845: nan,
#  1846: nan,
#  1847: nan,
#  1848: nan,
#  1849: nan,
#  1850: nan,
#  1851: nan,
#  1852: nan,
#  1853: nan,
#  1854: nan,
#  1855: nan,
#  1856: nan,
#  1857: nan,
#  1858: nan,
#  1859: nan,
#  1860: nan,
#  1861: nan,
#  1862: nan,
#  1863: nan,
#  1864: nan,
#  1865: nan,
#  1866: nan,
#  1867: nan,
#  1868: nan,
#  1869: nan,
#  1870: nan,
#  1871: nan,
#  1872: nan,
#  1873: nan,
#  1874: nan,
#  1875: nan,
#  1876: nan,
#  1877: nan,
#  1878: nan,
#  1879: nan,
#  1880: nan,
#  1881: nan,
#  1882: nan,
#  1883: nan,
#  1884: nan,
#  1885: nan,
#  1886: nan,
#  1887: nan,
#  1888: nan,
#  1889: nan,
#  1890: nan,
#  1891: nan,
#  1892: nan,
#  1893: nan,
#  1894: nan,
#  1895: nan,
#  1896: nan,
#  1897: nan,
#  1898: nan,
#  1899: nan,
#  1900: nan,
#  1901: nan,
#  1902: nan,
#  1903: nan,
#  1904: nan,
#  1905: nan,
#  1906: nan,
#  1907: nan,
#  1908: nan,
#  1909: nan,
#  1910: nan,
#  1911: nan,
#  1912: nan,
#  1913: nan,
#  1914: nan,
#  1915: nan,
#  1916: nan,
#  1917: nan,
#  1918: nan,
#  1919: nan,
#  1920: nan,
#  1921: 1.8599999999999994,
#  1922: -1.1499999999999986,
#  1923: 0.7999999999999972,
#  1924: 0.6900000000000048,
#  1925: -0.28999999999999915,
#  1926: -0.03999999999999915,
#  1927: 0.06999999999999318,
#  1928: 0.1700000000000017,
#  1929: 1.8200000000000074,
#  1930: 0.4199999999999875,
#  1931: 0.28000000000000114,
#  1932: -0.1699999999999875,
#  1933: -0.6400000000000006,
#  1934: 0.2599999999999909,
#  1935: 0.14000000000000057,
#  1936: 0.5499999999999972,
#  1937: 0.020000000000010232,
#  1938: -0.030000000000001137,
#  1939: 0.4299999999999926,
#  1940: -0.11999999999999034,
#  1941: -0.25,
#  1942: 0.539999999999992,
#  1943: 1.6299999999999955,
#  1944: 0.4200000000000017,
#  1945: -0.45999999999999375,
#  1946: 0.5999999999999943,
#  1947: -0.04999999999999716,
#  1948: 0.6200000000000045,
#  1949: -0.09000000000000341,
#  1950: -0.29999999999999716,
#  1951: 0.4099999999999966,
#  1952: 0.5799999999999983,
#  1953: 0.1700000000000017,
#  1954: 0.29000000000000625,
#  1955: -0.10999999999999943,
#  1956: 0.2799999999999869,
#  1957: 0.5400000000000063,
#  1958: -0.4099999999999966,
#  1959: 0.4200000000000017,
#  1960: 0.2599999999999909,
#  1961: -0.21999999999999886,
#  1962: 0.04999999999999716,
#  1963: -0.39000000000000057,
#  1964: 0.23000000000000398,
#  1965: -0.11999999999999034,
#  1966: 0.36999999999999034,
#  1967: -0.36999999999999034,
#  1968: 0.38999999999998636,
#  1969: -0.4199999999999875,
#  1970: 0.7999999999999972,
#  1971: 0.3199999999999932,
#  1972: 0.29000000000000625,
#  1973: -0.21000000000000796,
#  1974: 0.9300000000000068,
#  1975: 0.010000000000005116,
#  1976: 0.6799999999999926,
#  1977: 0.269999999999996,
#  1978: 0.5900000000000034,
#  1979: 0.23999999999999488,
#  1980: 0.21000000000000796,
#  1981: -0.060000000000002274,
#  1982: 0.7199999999999989,
#  1983: 0.07000000000000739,
#  1984: -0.0799999999999983,
#  1985: 0.6399999999999864,
#  1986: 0.020000000000010232,
#  1987: 0.2599999999999909,
#  1988: -0.14999999999999147,
#  1989: 0.8400000000000034,
#  1990: 0.4399999999999977,
#  1991: -0.010000000000005116,
#  1992: 0.5400000000000063,
#  1993: -0.15000000000000568,
#  1994: 0.4000000000000057,
#  1995: 0.0899999999999892,
#  1996: 0.28000000000000114,
#  1997: 0.4000000000000057,
#  1998: 0.25,
#  1999: 0.3400000000000034,
#  2000: 0.39000000000000057,
#  2001: 0.04999999999999716,
#  2002: 0.39000000000000057,
#  2003: 0.28999999999999204,
#  2004: 0.35999999999999943,
#  2005: 0.1700000000000017,
#  2006: -0.030000000000001137,
#  2007: 0.19000000000001194,
#  2008: 0.29999999999999716,
#  2009: 0.28999999999999204,
#  2010: 0.07000000000000739,
#  2011: 0.20999999999999375,
#  2012: 0.25,
#  2013: -0.030000000000001137,
#  2014: 0.0799999999999983,
#  2015: 0.21000000000000796,
#  2016: -0.09000000000000341,
#  2017: 0.5400000000000063,
#  2018: -0.010000000000005116,
#  2019: 0.4200000000000017}

# %% [markdown]
# Now to generalise one level further

# %%
def getYDiffSeriesDict(ySeriesDict):
    out = dict()
    for k, v in ySeriesDict.items():
        out[k] = getDiffsAsDict(v)
    return out

ySeriesDiffsDict = getYDiffSeriesDict(ySeriesDict)

ySeriesDiffsDict
# Out:
# {'Australia': {1816: nan,
#   1817: nan,
#   1818: nan,
#   1819: nan,
#   1820: nan,
#   1821: nan,
#   1822: nan,
#   1823: nan,
#   1824: nan,
#   1825: nan,
#   1826: nan,
#   1827: nan,
#   1828: nan,
#   1829: nan,
#   1830: nan,
#   1831: nan,
#   1832: nan,
#   1833: nan,
#   1834: nan,
#   1835: nan,
#   1836: nan,
#   1837: nan,
#   1838: nan,
#   1839: nan,
#   1840: nan,
#   1841: nan,
#   1842: nan,
#   1843: nan,
#   1844: nan,
#   1845: nan,
#   1846: nan,
#   1847: nan,
#   1848: nan,
#   1849: nan,
#   1850: nan,
#   1851: nan,
#   1852: nan,
#   1853: nan,
#   1854: nan,
#   1855: nan,
#   1856: nan,
#   1857: nan,
#   1858: nan,
#   1859: nan,
#   1860: nan,
#   1861: nan,
#   1862: nan,
#   1863: nan,
#   1864: nan,
#   1865: nan,
#   1866: nan,
#   1867: nan,
#   1868: nan,
#   1869: nan,
#   1870: nan,
#   1871: nan,
#   1872: nan,
#   1873: nan,
#   1874: nan,
#   1875: nan,
#   1876: nan,
#   1877: nan,
#   1878: nan,
#   1879: nan,
#   1880: nan,
#   1881: nan,
#   1882: nan,
#   1883: nan,
#   1884: nan,
#   1885: nan,
#   1886: nan,
#   1887: nan,
#   1888: nan,
#   1889: nan,
#   1890: nan,
#   1891: nan,
#   1892: nan,
#   1893: nan,
#   1894: nan,
#   1895: nan,
#   1896: nan,
#   1897: nan,
#   1898: nan,
#   1899: nan,
#   1900: nan,
#   1901: nan,
#   1902: nan,
#   1903: nan,
#   1904: nan,
#   1905: nan,
#   1906: nan,
#   1907: nan,
#   1908: nan,
#   1909: nan,
#   1910: nan,
#   1911: nan,
#   1912: nan,
#   1913: nan,
#   1914: nan,
#   1915: nan,
#   1916: nan,
#   1917: nan,
#   1918: nan,
#   1919: nan,
#   1920: nan,
#   1921: 1.8599999999999994,
#   1922: -1.1499999999999986,
#   1923: 0.7999999999999972,
#   1924: 0.6900000000000048,
#   1925: -0.28999999999999915,
#   1926: -0.03999999999999915,
#   1927: 0.06999999999999318,
#   1928: 0.1700000000000017,
#   1923: 0.5999999999999943,
#   1924: -0.8399999999999963,
#   1925: -0.39000000000000057,
#   1926: 1.7800000000000011,
#   1927: -0.3300000000000054,
#   1928: -1.1699999999999946,
#   1929: 2.559999999999995,
#   1930: 0.10000000000000142,
#   1931: 0.3200000000000003,
#   1932: 0.4299999999999997,
#   1933: 0.6499999999999986,
#   1934: -0.01999999999999602,
#   1935: 0.4799999999999969,
#   1936: 0.3500000000000014,
#   1937: -0.17999999999999972,
#   1938: 0.6199999999999974,
#   1939: -9.949999999999996,
#   1940: 7.82,
#   1941: 0.01999999999999602,
#   1942: -4.140000000000001,
#   1943: -6.1299999999999955,
#   1944: 7.759999999999998,
#   1945: 7.43,
#   1946: 1.5900000000000034,
#   1947: 1.8299999999999983,
#   1948: -0.8799999999999955,
#   1949: 1.4799999999999898,
#   1950: -0.28999999999999204,
#   1951: 1.2999999999999972,
#   1952: -0.07000000000000739,
#   1953: 0.8700000000000045,
#   1954: 0.25,
#   1955: 0.01999999999999602,
#   1956: 0.4300000000000068,
#   1957: 1.2199999999999989,
#   1958: 0.060000000000002274,
#   1959: 0.18999999999999773,
#   1960: 0.5999999999999943,
#   1961: -0.4899999999999949,
#   1962: -0.15000000000000568,
#   1963: 0.960000000000008,
#   1964: -0.1700000000000017,
#   1965: 0.4000000000000057,
#   1966: -0.010000000000005116,
#   1967: -0.01999999999999602,
#   1968: -0.28000000000000114,
#   1969: 0.8900000000000006,
#   1970: -0.020000000000010232,
#   1971: 0.2400000000000091,
#   1972: 0.1599999999999966,
#   1973: 0.3299999999999983,
#   1974: 0.10000000000000853,
#   1975: 0.21999999999999886,
#   1976: 0.6099999999999994,
#   1977: 0.11999999999999034,
#   1978: 0.27000000000001023,
#   1979: 0.10999999999999943,
#   1980: 0.1700000000000017,
#   1981: 0.36999999999999034,
#   1982: -0.030000000000001137,
#   1983: 0.480000000000004,
#   1984: 0.09000000000000341,
#   1985: 0.269999999999996,
#   1986: 0.5700000000000074,
#   1987: 0.25,
#   1988: 0.14000000000000057,
#   1989: 0.29999999999999716,
#   1990: 0.1700000000000017,
#   1991: 0.28000000000000114,
#   1992: 0.05999999999998806,
#   1993: 0.4200000000000017,
#   1994: 0.10000000000000853,
#   1995: 0.18999999999999773,
#   1996: 0.35999999999999943,
#   1997: 0.1700000000000017,
#   1998: 0.1599999999999966,
#   1999: 0.29999999999999716,
#   2000: 0.18000000000000682,
#   2001: 0.18999999999999773,
#   2002: 0.010000000000005116,
#   2003: 0.9199999999999875,
#   2004: -0.009999999999990905,
#   2005: 0.4099999999999966,
#   2006: 0.21999999999999886,
#   2007: 0.0799999999999983,
#   2008: 0.12000000000000455,
#   2009: 0.25,
#   2010: 0.37999999999999545,
#   2011: -0.04999999999999716,
#   2012: 0.23999999999999488,
#   2013: 0.46999999999999886,
#   2014: -0.28999999999999204,
#   2015: 0.25,
#   2016: 0.03999999999999204,
#   2017: 0.13000000000000966,
#   2018: 0.1700000000000017,
#   2019: -0.5300000000000011}}

# %% [markdown]
# I think this is the solution I need. I'll now turn it into a function called from 2d.py
