# %%
from dash import html, dcc
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../assets/data/mx.csv")

# %%
d2 = df[
    (df['cntry'] == 'USA') & 
    (df['sex'] == 'female') & 
    (df['age'] <= 90)
]
d2.reset_index(drop = True)
# Out:
#      country                       link cntry  year  age     sex        mx
# 0     U.S.A.  /Country/Country?cntr=USA   USA  1933    0  female  0.054177
# 1     U.S.A.  /Country/Country?cntr=USA   USA  1933    1  female  0.008866
# 2     U.S.A.  /Country/Country?cntr=USA   USA  1933    2  female  0.004025
# 3     U.S.A.  /Country/Country?cntr=USA   USA  1933    3  female  0.002869
# 4     U.S.A.  /Country/Country?cntr=USA   USA  1933    4  female  0.002230
# ...      ...                        ...   ...   ...  ...     ...       ...
# 8094  U.S.A.  /Country/Country?cntr=USA   USA  2021   86  female  0.092279
# 8095  U.S.A.  /Country/Country?cntr=USA   USA  2021   87  female  0.103615
# 8096  U.S.A.  /Country/Country?cntr=USA   USA  2021   88  female  0.116777
# 8097  U.S.A.  /Country/Country?cntr=USA   USA  2021   89  female  0.131153
# 8098  U.S.A.  /Country/Country?cntr=USA   USA  2021   90  female  0.144996
#
# [8099 rows x 7 columns]

# %% [markdown]
# We'll now first create the data array, then use the same approach to produce the text array

# %%
mx_array = d2[
    ['age', 'year', 'mx']
].pivot(
    index = 'year', columns = 'age', values = 'mx'
)
mx_array = np.array(mx_array)

# %%
d2['text'] = d2.apply(
    lambda x: "In %s at age %s the %s mortality rate was %1.4f" % (
        x['year'], x['age'], x['sex'], x['mx']
    ), axis = 1
)

d2
# Out:
# /var/folders/cp/3jc3y0nj5698z6h5nk3yzng00000gn/T/ipykernel_99255/2778244196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2['text'] = d2.apply(
#         country                       link cntry  year  age     sex        mx  \
# 1200798  U.S.A.  /Country/Country?cntr=USA   USA  1933    0  female  0.054177
# 1200801  U.S.A.  /Country/Country?cntr=USA   USA  1933    1  female  0.008866
# 1200804  U.S.A.  /Country/Country?cntr=USA   USA  1933    2  female  0.004025
# 1200807  U.S.A.  /Country/Country?cntr=USA   USA  1933    3  female  0.002869
# 1200810  U.S.A.  /Country/Country?cntr=USA   USA  1933    4  female  0.002230
# ...         ...                        ...   ...   ...  ...     ...       ...
# 1230360  U.S.A.  /Country/Country?cntr=USA   USA  2021   86  female  0.092279
# 1230363  U.S.A.  /Country/Country?cntr=USA   USA  2021   87  female  0.103615
# 1230366  U.S.A.  /Country/Country?cntr=USA   USA  2021   88  female  0.116777
# 1230369  U.S.A.  /Country/Country?cntr=USA   USA  2021   89  female  0.131153
# 1230372  U.S.A.  /Country/Country?cntr=USA   USA  2021   90  female  0.144996
#
#                                                       text
# 1200798  In 1933 at age 0 the female mortality rate was...
# 1200801  In 1933 at age 1 the female mortality rate was...
# 1200804  In 1933 at age 2 the female mortality rate was...
# 1200807  In 1933 at age 3 the female mortality rate was...
# 1200810  In 1933 at age 4 the female mortality rate was...
# ...                                                    ...
# 1230360  In 2021 at age 86 the female mortality rate wa...
# 1230363  In 2021 at age 87 the female mortality rate wa...
# 1230366  In 2021 at age 88 the female mortality rate wa...
# 1230369  In 2021 at age 89 the female mortality rate wa...
# 1230372  In 2021 at age 90 the female mortality rate wa...
#
# [8099 rows x 8 columns]

# %%
text_array = d2[
    ['age', 'year', 'text']
].pivot(
    index = 'year', columns = 'age', values = 'text'
)
text_array = np.array(text_array)
text_array
# Out:
# array([['In 1933 at age 0 the female mortality rate was 0.0542',
#         'In 1933 at age 1 the female mortality rate was 0.0089',
#         'In 1933 at age 2 the female mortality rate was 0.0040', ...,
#         'In 1933 at age 88 the female mortality rate was 0.2054',
#         'In 1933 at age 89 the female mortality rate was 0.2210',
#         'In 1933 at age 90 the female mortality rate was 0.2360'],
#        ['In 1934 at age 0 the female mortality rate was 0.0602',
#         'In 1934 at age 1 the female mortality rate was 0.0099',
#         'In 1934 at age 2 the female mortality rate was 0.0045', ...,
#         'In 1934 at age 88 the female mortality rate was 0.2052',
#         'In 1934 at age 89 the female mortality rate was 0.2218',
#         'In 1934 at age 90 the female mortality rate was 0.2389'],
#        ['In 1935 at age 0 the female mortality rate was 0.0536',
#         'In 1935 at age 1 the female mortality rate was 0.0083',
#         'In 1935 at age 2 the female mortality rate was 0.0038', ...,
#         'In 1935 at age 88 the female mortality rate was 0.2088',
#         'In 1935 at age 89 the female mortality rate was 0.2262',
#         'In 1935 at age 90 the female mortality rate was 0.2415'],
#        ...,
#        ['In 2019 at age 0 the female mortality rate was 0.0050',
#         'In 2019 at age 1 the female mortality rate was 0.0003',
#         'In 2019 at age 2 the female mortality rate was 0.0002', ...,
#         'In 2019 at age 88 the female mortality rate was 0.1051',
#         'In 2019 at age 89 the female mortality rate was 0.1213',
#         'In 2019 at age 90 the female mortality rate was 0.1351'],
#        ['In 2020 at age 0 the female mortality rate was 0.0048',
#         'In 2020 at age 1 the female mortality rate was 0.0003',
#         'In 2020 at age 2 the female mortality rate was 0.0002', ...,
#         'In 2020 at age 88 the female mortality rate was 0.1248',
#         'In 2020 at age 89 the female mortality rate was 0.1390',
#         'In 2020 at age 90 the female mortality rate was 0.1576'],
#        ['In 2021 at age 0 the female mortality rate was 0.0051',
#         'In 2021 at age 1 the female mortality rate was 0.0004',
#         'In 2021 at age 2 the female mortality rate was 0.0002', ...,
#         'In 2021 at age 88 the female mortality rate was 0.1168',
#         'In 2021 at age 89 the female mortality rate was 0.1312',
#         'In 2021 at age 90 the female mortality rate was 0.1450']],
#       dtype=object)

# %%
fig = go.Figure(data = [
    go.Surface(
        z = mx_array, text = text_array,
        surfacecolor = np.log(mx_array),
        hovertemplate = '%{text}'
    )
])

fig.update_layout(
    scene = dict(
        zaxis = dict(title = "Logged mortality", type="log"),
        xaxis = dict(title = "Age in years"),
        yaxis = dict(title = "Year")

    )
)

fig.show()

# %% [markdown]
# This was fairly straightforward once the approach was figured out in the simple case.
